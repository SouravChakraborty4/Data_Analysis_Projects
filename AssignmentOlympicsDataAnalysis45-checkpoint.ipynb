# %%
#Assignment:Olympics Data Analysis
#StudentID:T181045
#Name: Sourav Chakraborty

#Importing the datasets

# %%
import pandas as pd

# %%
DatasetAthlete_events = pd.read_csv("athlete_events.csv")
DatasetAthlete_events
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
DatasetRegions = pd.read_csv("regions1.csv")
DatasetRegions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
#joining the data based on appropriate column.

# %%
dataset1 = pd.merge(DatasetAthlete_events, DatasetRegions, on='NOC', how='left')
dataset1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Replacing nan values with the column’s mean, For numeric columns

# %%
import pandas as pd
import numpy as np

# %%
dataset1['Age'] = dataset1['Age'].fillna(dataset1['Age'].mean())
dataset1['Height'] = dataset1['Height'].fillna(dataset1['Height'].mean())
dataset1['Weight'] = dataset1['Weight'].fillna(dataset1['Weight'].mean())
dataset1
# Out:
#             ID                      Name Sex   Age     Height     Weight  \
# 0            1                 A Dijiang   M  24.0  180.00000  80.000000
# 1            2                  A Lamusi   M  23.0  170.00000  60.000000
# 2            3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3            4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4            5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
# ...        ...                       ...  ..   ...        ...        ...
# 271111  135569                Andrzej ya   M  29.0  179.00000  89.000000
# 271112  135570                  Piotr ya   M  27.0  176.00000  59.000000
# 271113  135570                  Piotr ya   M  27.0  176.00000  59.000000
# 271114  135571        Tomasz Ireneusz ya   M  30.0  185.00000  96.000000
# 271115  135571        Tomasz Ireneusz ya   M  34.0  185.00000  96.000000
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
#Top 10 countries with most gold, silver, bronze medal

# %%
goldMedals = dataset1[(dataset1.Medal == 'Gold')]
goldMedals
goldMedals.region.value_counts().reset_index(name='Medal').head(10)
# Out:
#      index  Medal
# 0      USA   2638
# 1   Russia   1599
# 2  Germany   1301
# 3       UK    678
# 4    Italy    575
# 5   France    501
# 6   Sweden    479
# 7   Canada    463
# 8  Hungary    432
# 9   Norway    378

# %%
SilverMedals = dataset1[(dataset1.Medal == 'Silver')]
SilverMedals
SilverMedals.region.value_counts().reset_index(name='Medal').head(10)
# Out:
#        index  Medal
# 0        USA   1641
# 1    Germany   1195
# 2     Russia   1170
# 3         UK    739
# 4     France    610
# 5      Italy    531
# 6     Sweden    522
# 7  Australia    459
# 8     Canada    438
# 9     Norway    361

# %%
BronzeMedals = dataset1[(dataset1.Medal == 'Bronze')]
BronzeMedals
BronzeMedals.region.value_counts().reset_index(name='Medal').head(10)
# Out:
#        index  Medal
# 0        USA   1358
# 1    Germany   1260
# 2     Russia   1178
# 3     France    666
# 4         UK    651
# 5     Sweden    535
# 6      Italy    531
# 7  Australia    522
# 8     Canada    451
# 9    Finland    432

# %%
#Finding the distribution of gold medalists according to their age.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]

# %%
plt.figure(figsize=(35, 20))
plt.tight_layout()
sns.countplot(goldMedals['Age'])
plt.title('Distribution of Gold Medalists according to age')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Gold Medalists according to age')

# %%
#Highest playing sport that women play who are above 36 years--

# %%
WomenInOlympics = dataset1[(dataset1.Sex == 'F') & (dataset1.Age > 36)]
WomenInOlympics.head()
# Out:
#       ID                                 Name Sex   Age     Height     Weight  \
# 280  147                        Joanne Abbott   F  41.0  160.00000  57.000000
# 284  151  Mary Perkins Ives Abbott (Perkins-)   F  42.0  175.33897  70.702393
# 287  154                      Khadija Abbouda   F  40.0  165.00000  57.000000
# 735  422            Julianne "Anne" Abernathy   F  38.0  165.00000  75.000000
# 736  422            Julianne "Anne" Abernathy   F  40.0  165.00000  75.000000
#
#                              Team  NOC        Games  Year  Season  \
# 280                        Canada  CAN  1996 Summer  1996  Summer
# 284                 United States  USA  1900 Summer  1900  Summer
# 287                       Morocco  MAR  2008 Summer  2008  Summer
# 735  United States Virgin Islands  ISV  1992 Winter  1992  Winter
# 736  United States Virgin Islands  ISV  1994 Winter  1994  Winter
#
#             City    Sport                                Event Medal  \
# ...

# %%
WomenInOlympics.Sport.value_counts().reset_index(name='Sport').head(1)
# Out:
#            index  Sport
# 0  Equestrianism    448

# %%
#Sports played by men and women who weighs over 120--

# %%
GamesAccordingToWeight=dataset1[(dataset1.Weight > 120)]
GamesAccordingToWeight.head()
# Out:
#       ID                            Name Sex   Age  Height  Weight  \
# 57    18            Timo Antero Aaltonen   M  31.0   189.0   130.0
# 80    22                   Andreea Aanei   F  22.0   170.0   125.0
# 588  338            Muminzhon Abdullayev   M  22.0   190.0   130.0
# 589  338            Muminzhon Abdullayev   M  26.0   190.0   130.0
# 620  359  Andrey Khakimovich Abduvaliyev   M  26.0   190.0   125.0
#
#              Team  NOC        Games  Year  Season            City  \
# 57        Finland  FIN  2000 Summer  2000  Summer          Sydney
# 80        Romania  ROU  2016 Summer  2016  Summer  Rio de Janeiro
# 588    Uzbekistan  UZB  2012 Summer  2012  Summer          London
# 589    Uzbekistan  UZB  2016 Summer  2016  Summer  Rio de Janeiro
# 620  Unified Team  EUN  1992 Summer  1992  Summer       Barcelona
#
#              Sport                                           Event Medal  \
# 57       Athletics                        Athletics Men's Shot Put   NaN
# ...

# %%
GamesAccordingToWeight.Sport.value_counts().reset_index(name='Sport').head(100)
# Out:
#             index  Sport
# 0       Athletics    410
# 1   Weightlifting    221
# 2            Judo    184
# 3       Wrestling    169
# 4      Basketball     47
# 5        Shooting     34
# 6         Sailing     16
# 7         Archery      8
# 8       Bobsleigh      8
# 9          Boxing      5
# 10       Handball      4
# 11       Skeleton      1
# 12         Rowing      1
# 13     Water Polo      1

# %%
#Comparison between Different WeightC lass Women
#sports event played by woman over 120kg

# %%
weightClass = dataset1[(dataset1.Sex == 'F') & (dataset1.Weight > 120)]
weightClass
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 80          22                     Andreea Aanei   F  22.0   170.0   125.0
# 36304    18653             Michelle Denee Carter   F  22.0   176.0   136.0
# 36305    18653             Michelle Denee Carter   F  26.0   176.0   136.0
# 36306    18653             Michelle Denee Carter   F  30.0   176.0   136.0
# 54662    28042                       Yosra Dhieb   F  20.0   178.0   123.0
# ...        ...                               ...  ..   ...     ...     ...
# 267561  133858  Vanessa Martina Zambotti Barreto   F  22.0   175.0   125.0
# 267562  133858  Vanessa Martina Zambotti Barreto   F  26.0   175.0   125.0
# 267563  133858  Vanessa Martina Zambotti Barreto   F  30.0   175.0   125.0
# 267564  133858  Vanessa Martina Zambotti Barreto   F  34.0   175.0   125.0
# 269393  134800                         Zhou Lulu   F  24.0   175.0   133.0
#
# ...

# %%
#sports event played by woman less than 120kg

# %%
weightClass1 = dataset1[(dataset1.Sex == 'F') & (dataset1.Weight < 120)]
weightClass1
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 4            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5             Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5             Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5             Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271099  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271110  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
#According to the Analysis less sports event played by woman over 120kg as there are less individuals in that (sports event played by woman over 120kg)dataset

# %%
#Scatter plot for gold winners according to their age and weight

# %%
goldMedalWinner = dataset1[(dataset1.Medal == 'Gold')]
goldMedalWinner
# Out:
#             ID                                 Name Sex   Age     Height  \
# 3            4                 Edgar Lindenau Aabye   M  34.0  175.33897
# 42          17              Paavo Johannes Aaltonen   M  28.0  175.00000
# 44          17              Paavo Johannes Aaltonen   M  28.0  175.00000
# 48          17              Paavo Johannes Aaltonen   M  28.0  175.00000
# 60          20                   Kjetil Andr Aamodt   M  20.0  176.00000
# ...        ...                                  ...  ..   ...        ...
# 270981  135503                      Zurab Zviadauri   M  23.0  182.00000
# 271009  135520                          Julia Zwehl   F  28.0  167.00000
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0  200.00000
# 271049  135545                      Henk Jan Zwolle   M  31.0  197.00000
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0  168.00000
#
#            Weight            Team  NOC        Games  Year  Season  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 10))
AX = sns.scatterplot(x="Age", y="Weight",data= goldMedalWinner)
plt.title('Age vs Weight of Olympic Gold Medalists')
# Out:
# Text(0.5, 1.0, 'Age vs Weight of Olympic Gold Medalists')

# %%
# I see that there is a increase of weight till 24, and as well as the age increases the weight range also increases.
#And from 25 to 33 age the weight range remains same, though there are some outliers in the date. 
#Till age 40 the weight of an individual athlete varies from(40-120)--[without Considering Outliers]
#After that as the age increases the weight range decreases. It Indicates from 45 to 65 athletes are about 65-75 KG.
